# %%
#Bar chart
import pandas as pd
import matplotlib.pyplot as plt
df_used_cars=pd.read_csv('bar_chart_data.csv')
plt.bar(x=df_used_cars['Brand'],height=df_used_cars['Cars Listings'])
plt.show()

# %%
#Bar chart
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()
used_cars=pd.read_csv('bar_chart_data.csv')
plt.bar(x=used_cars['Brand'],height=used_cars['Cars Listings'],color='red')
plt.xticks(rotation=45,fontsize=13)
plt.yticks(fontsize=13)
plt.title('cars listings by brand',fontsize=16,fontweight='bold')
plt.ylabel('number of listings',fontsize=13)
plt.show()
plt.savefig('used cars plot.png')

# %%
#bar chart
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_palette('colorblind')
cities=pd.read_csv('bar_chart_homework_data.csv')
plt.figure(figsize=(10,8))
plt.bar(x=cities['Cities'],height=cities['Frequency'],color='Gold')
plt.xticks(fontsize=13,fontweight='bold')
plt.yticks(fontsize=13)
plt.title('cities propotional to resturants')
plt.xlabel('Cities',fontweight='bold')
plt.ylabel('Frequency',fontweight='bold')
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set_palette('colorblind')
df_engine=pd.read_csv('pie_chart_data.csv')
plt.figure(figsize=(10,8))
plt.pie(df_engine['Number of Cars'],
       labels=df_engine['Engine Fuel Type'].values,
       autopct='%.2f%%',
       textprops={'size':'x-large','fontweight':'bold','rotation':45,'color':'w'})
plt.legend()
plt.title('cars by engine type',fontsize=18,fontweight='bold')
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set_palette('colorblind')
engine=pd.read_csv('pie_chart_data.csv')
plt.figure(figsize=(10,8))
plt.pie(engine['Number of Cars'],
       labels=df_engine['Engine Fuel Type'],
        autopct='%.2f%%',
       textprops={'size':'x-large','fontweight':'bold','rotation':45,'color':'black'})
plt.legend()
plt.title('cars by engine type',fontsize=18,fontweight='bold')
plt.show()

# %%
#stacked area chart
engine_type=pd.read_csv('stacked_area_chart_data.csv')
color=['y','r','b']
label=['Diesel','Petrol','Gas']
sns.set_style('white')
plt.figure(figsize=(12,6))
plt.stackplot(engine_type['Year'],
              engine_type['Diesel'],
              engine_type['Petrol'],
              engine_type['Gas'],
             colors=color,
             edgecolor='none')
plt.xticks(engine_type['Year'],rotation=45)
plt.legend(labels=label,loc='upper right')
plt.ylabel('No of cars')
plt.title('Popularity of fuel type from 1982 to 2016',fontsize='x-large',fontweight='bold')
sns.despine(right=True,top=True)
plt.show()

# %%
#stacked area chart
flights=pd.read_csv('area_chart_homework_data.csv')
color=['red','blue','green']
label=['International','Domestic']
sns.set_style('darkgrid')
plt.figure(figsize=(18,8))
plt.stackplot(flights['Date'],
             flights['International'],
             flights['Domestic'],
             flights['Services'],
             colors=color,
             edgecolor='none')
plt.xticks(flights['Date'],rotation=45)
plt.legend(labels=label,loc='upper right')
plt.xlabel('Date')
plt.title('Graph representing flights route and service',fontsize='x-large',fontweight='bold')
sns.despine(right=True,top=True)
plt.show()

# %%
#line chart
x=[0,1,2,3]
y=[10,20,25,30]
plt.plot(x,y)
current_ticks=plt.xticks([0,1,2,3])
print(current_ticks)
plt.show()
# Out:
# ([<matplotlib.axis.XTick object at 0x1254c8150>, <matplotlib.axis.XTick object at 0x12552b210>, <matplotlib.axis.XTick object at 0x12553a2d0>, <matplotlib.axis.XTick object at 0x12555d850>], [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2'), Text(3, 0, '3')])

# %%
#Line chart 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
GSPC=pd.read_csv('line chart returns1020.csv')
GSPC['new date']=pd.to_datetime(GSPC['Date'])
labels=['gspc','ftse']
plt.figure(figsize=(20,8))
plt.plot(GSPC['new date'],GSPC['GSPCRet'],color='r')
plt.plot(GSPC['new date'],GSPC['FTSERet'],color='b')
plt.title('s & p vs ftse returns from 2008 to 2010',fontsize=14,fontweight='bold')
plt.legend(labels=labels)
plt.ylabel('returns',fontsize=18,fontweight='bold')
plt.xlabel('date',fontsize=18,fontweight='bold')
plt.show()

# %%
#line chart specified time frame
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()
sp_ftse=pd.read_csv('line_chart_data.csv')
sp_ftse['new_date']=pd.to_datetime(sp_ftse["Date"])
mask = (sp_ftse['new_date'] >= '2008-07-01') & (sp_ftse['new_date'] <= '2008-12-31')
sp_ftse2008 = sp_ftse.loc[mask]
labels=['s&p 500','ftse 100']
plt.figure(figsize=(20,8))
plt.plot(sp_ftse2008['new_date'],sp_ftse2008['GSPC500'],color='r')
plt.plot(sp_ftse2008['new_date'],sp_ftse2008['FTSE100'],color='b')
plt.title('s & p vs ftse returns from 2008 to 2010',fontsize=14,fontweight='bold')
plt.ylabel('returns',fontsize=18,fontweight='bold')
plt.xlabel('date',fontsize=18,fontweight='bold')
plt.legend(labels=labels,fontsize='x-large')
plt.show()

# %%
#histogram
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_style('white')
df_real_estate=pd.read_csv('histogram_data.csv')
plt.figure(figsize=(8,6))
plt.hist(df_real_estate['Price'],
        bins=8,
        color='b')
plt.title('Distribution of real estate prices',fontsize=14,fontweight='bold')
plt.xlabel('price in (000.$)')
plt.ylabel('No of properties')
sns.despine(top=True,right=True)
plt.show()

# %%
#histogram
income=pd.read_csv('histogram_survey_data.csv')
plt.figure(figsize=(10,8))
plt.hist(income['Income'],
        bins=8,
        color='b')
plt.title("Income under category")
plt.xlabel('price in 000$')
plt.ylabel('people under that category')
# Out:
# Text(0, 0.5, 'people under that category')

# %%
#scatter plot using matplotlib library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
real_estate=pd.read_csv('Scatter_data.csv')
plt.figure(figsize=(12,8))
scatterplot=plt.scatter(real_estate['Area (ft.)'],
                        real_estate['Price'],
                        alpha=0.6,
                        c=real_estate['Building Type'],
                        cmap='viridis')#colormap like viridis,mako
plt.legend(*scatterplot.legend_elements(),
           loc='upper left',
           title='Building Type')
plt.title('Relationship between area and price of calforina Real estate',fontsize=14,fontweight='bold')
plt.xlabel("area(sq.ft)",fontweight='bold')
plt.ylabel("Price(000's of $)")
plt.show()

# %%
#scatter plot using seaborn liberary

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

marks = pd.read_csv('scatter_home.csv')
plt.figure(figsize=(12,8))
sns.scatterplot(x='SAT',
                y='GPA',
                data=marks,
                hue='GPA',
                palette='mako',
                s=100)
plt.title('Relationship between students GPA\'s and SAT marks', fontsize=14, fontweight='bold')
plt.show()

# %%
#Regression plot
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
ad_exp=pd.read_csv('regression plot.csv')
plt.figure(figsize=(10,8))
sns.regplot(x='Budget',
           y='Sales',
           data=ad_exp,
           scatter_kws={'color':'k'},
           line_kws={'color':'red'})
plt.xlabel('ad expenditure in(ooo\'s $)')
plt.ylabel('Sales in(000\'s units)')
plt.title('Effect on ad expenditure on sales',fontsize=14,fontweight='bold')
plt.show()

# %%
#bar and line chart
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_style('white')
py=pd.read_csv('bar_line_chart_data.csv')
fig,ax=plt.subplots(figsize=(10,7))
ax.bar(py['Year'],
      py['Participants'],
       color='k')
ax1=ax.twinx()
ax1.plot(py['Year'],
        py['Python Users'],
        color='#b60000',
        marker='D')
plt.show()
